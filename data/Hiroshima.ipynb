# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Hiroshima 小学校.csv')

# %%
df
# Out:
#          名称  名称かな                所在地           TEL           FAX  \
# 0     白島小学校   NaN     広島市中区西白島町26番3号  082-221-3012  082-211-3519
# 1     基町小学校   NaN       広島市中区基町20番2号  082-228-0193  082-228-4589
# 2     幟町小学校   NaN       広島市中区幟町3番10号  082-221-3013  082-211-3509
# 3     袋町小学校   NaN       広島市中区袋町6番36号  082-247-9241  082-240-1384
# 4     竹屋小学校   NaN      広島市中区鶴見町8番49号  082-241-9138  082-248-3138
# ..      ...   ...                ...           ...           ...
# 136  彩が丘小学校   NaN  広島市佐伯区河内南二丁目10番1号  082-928-1239  082-928-4538
# 137  湯来東小学校   NaN  広島市佐伯区湯来町麦谷1803-1  0829-83-0513  0829-83-0213
# 138  湯来西小学校   NaN    広島市佐伯区湯来町多田2416  0829-85-0315  0829-85-0139
# 139  湯来南小学校   NaN  広島市佐伯区湯来町白砂3555-1  0829-86-0611  0829-86-1771
# 140  石内北小学校   NaN  広島市佐伯区石内北三丁目23番1号  082-941-5007  082-941-0730
#
#                                                    URL  備考  郵便番号        施設ID  \
# 0        http://www.hakushima-e.edu.city.hiroshima.jp/ NaN   NaN  A025000001
# 1    http://www.motomachi-e.edu.city.hiroshima.jp/i... NaN   NaN  A025000002
# 2       http://www.noborichou-e.edu.city.hiroshima.jp/ NaN   NaN  A025000003
# 3      http://www.fukuromachi-e.edu.city.hiroshima.jp/ NaN   NaN  A025000004
# 4           http://www.takeya-e.edu.city.hiroshima.jp/ NaN   NaN  A025000005
# ..                                                 ...  ..   ...         ...
# 136       http://www.ayagaoka-e.edu.city.hiroshima.jp/ NaN   NaN  A025000137
# 137    http://www.yukihigashi-e.edu.city.hiroshima.jp/ NaN   NaN  A025000138
# 138      http://www.yukinishi-e.edu.city.hiroshima.jp/ NaN   NaN  A025000139
# 139     http://www.yukiminami-e.edu.city.hiroshima.jp/ NaN   NaN  A025000140
# 140  http://cms.edu.city.hiroshima.jp/weblog/index.... NaN   NaN  A025000141
#
#              経度         緯度     分類
# 0    132.461490  34.404434  市立小学校
# 1    132.456619  34.403036  市立小学校
# 2    132.466525  34.396528  市立小学校
# 3    132.458783  34.391861  市立小学校
# 4    132.467145  34.385340  市立小学校
# ..          ...        ...    ...
# 136  132.344022  34.410255  市立小学校
# 137  132.316100  34.525669  市立小学校
# 138  132.233883  34.469944  市立小学校
# 139  132.290038  34.433477  市立小学校
# 140  132.385960  34.443318  市立小学校
#
# [141 rows x 12 columns]

# %%
df.shape
# Out:
# (141, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   名称      141 non-null    object
#  1   名称かな    0 non-null      float64
#  2   所在地     141 non-null    object
#  3   TEL     141 non-null    object
#  4   FAX     141 non-null    object
#  5   URL     141 non-null    object
#  6   備考      0 non-null      float64
#  7   郵便番号    0 non-null      float64
#  8   施設ID    141 non-null    object
#  9   経度      141 non-null    float64
#  10  緯度      141 non-null    float64
#  11  分類      141 non-null    object
# dtypes: float64(5), object(7)
# memory usage: 13.3+ KB

# %%
df.columns.to_list()
# Out:
# ['名称',
#  '名称かな',
#  '所在地',
#  'TEL',
#  'FAX',
#  'URL',
#  '備考',
#  '郵便番号',
#  '施設ID',
#  '経度',
#  '緯度',
#  '分類']

# %%
df[['名称','経度','緯度']]
# Out:
#          名称          経度         緯度
# 0     白島小学校  132.461490  34.404434
# 1     基町小学校  132.456619  34.403036
# 2     幟町小学校  132.466525  34.396528
# 3     袋町小学校  132.458783  34.391861
# 4     竹屋小学校  132.467145  34.385340
# ..      ...         ...        ...
# 136  彩が丘小学校  132.344022  34.410255
# 137  湯来東小学校  132.316100  34.525669
# 138  湯来西小学校  132.233883  34.469944
# 139  湯来南小学校  132.290038  34.433477
# 140  石内北小学校  132.385960  34.443318
#
# [141 rows x 3 columns]

# %%
df['経度']
# Out:
# 0      132.461490
# 1      132.456619
# 2      132.466525
# 3      132.458783
# 4      132.467145
#           ...
# 136    132.344022
# 137    132.316100
# 138    132.233883
# 139    132.290038
# 140    132.385960
# Name: 経度, Length: 141, dtype: float64

# %%
center_lat = df['経度'].mean()
center_lon = df['緯度'].mean()

# %%
m = folium.Map(location=[center_lat,center_lon], zoom_start=12)

# df をループしてマーカーを作る
for index, row in df.iterrows():
    latlon = [row['緯度'],row['経度']]
    folium.Marker(latlon, 
                  popup='<div style="width:350px">'+row['description']+'</div>', 
                  tooltip=row['名称'],
                  icon=folium.Icon(color=row['color']
                )).add_to(m)

# show the map
m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/envs/gis/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'description'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 7
#       4 for index, row in df.iterrows():
#       5     latlon = [row['緯度'],row['経度']]
#       6     folium.Marker(latlon,
# ----> 7                   popup='<div style="width:350px">'+row['description']+'</div>',
#       8                   tooltip=row['名称'],
#       9                   icon=folium.Icon(color=row['color']
#      10                 )).add_to(m)
#      12 # show the map
#      13 m
#
# File /opt/miniconda3/envs/gis/lib/python3.11/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File /opt/miniconda3/envs/gis/lib/python3.11/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File /opt/miniconda3/envs/gis/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'description'
